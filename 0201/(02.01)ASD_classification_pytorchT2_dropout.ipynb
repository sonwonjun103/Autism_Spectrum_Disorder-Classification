# %% [markdown]
# # 0. Library Import

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

import time
import cv2
import random
import gc
import warnings

from PIL import Image
from glob import glob
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import SimpleITK as sitk
import pydicom as dcm

import torch
import torch.nn as nn
import torch.nn.functional as F

from torchvision import datasets
from torchvision.transforms import *
from torchvision.transforms import Compose

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import ConcatDataset
from torch.autograd import Variable

# %%
CFG={'Image_Size':256,
    'EPOCHS':100,
    'BATCH_SIZE':8,
    'Learning_rate':1e-3,
    'beta_1':0.9,
    'beta_2':0.99,
    'eps':0.00000001,
     'weight_decay':0.000001,
    'Channel_size':8,
    'SEED':42}

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Check Gpu Server

# %%
if torch.cuda.is_available():
    device="cuda"
else:
    device="cpu"
    
print(f"device  : {device}")
# Out:
# device  : cuda

# %%
print(f"Name of the graphic card : {torch.cuda.get_device_name(0)}")
print(f"Number of gpu : {torch.cuda.device_count()}")
# Out:
# Name of the graphic card : NVIDIA GeForce RTX 4090
# Number of gpu : 2

# %% [markdown]
# ### Make Trash can

# %%
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ### Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED']=str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=True

seed_everything(CFG['SEED'])

# %% [markdown]
# # 2. Get Data Path

# %%
path_asd='C:\\Users\\PC00\\Desktop\\ASD_data\\ASD\\'
path_control='C:\\Users\\PC00\\Desktop\\ASD_data\\CONTROL\\'

asd_p=os.listdir(path_asd)
control_p=os.listdir(path_control)

MRI_image=['MAGIC_T2']
all_image_path=[]

for name in asd_p:
    path=''
    for image in MRI_image:
        path=path_asd+name+'\\'+'aNew'+'\\'
        path=path+image+'\\'
        if 'Test' in path or '3564' in path or '3395' in path or '3278' in path or '3466' in path or '3624' in path or '3603' in path or '3632' in path or '3663' in path:
            pass
        else:
            all_image_path.append(path)
print("ASD Image Data : " , len(all_image_path)) 
for name in control_p:
    path=''
    for image in MRI_image:
        path=path_control+name+'\\'+'aNew'+'\\'
        path=path+image+'\\'
        if 'Test' in path or '3564' in path or '3395' in path or '3278' in path or '3466' in path or '3624' in path or '3603' in path or '3632' in path or '3663' in path:
            pass
        else:
            all_image_path.append(path)
        
print("ASD+TC Image Data : " ,len(all_image_path))
# Out:
# ASD Image Data :  203
# ASD+TC Image Data :  261

# %%
for info in all_image_path:
    print(info)
# Out:
# C:\Users\PC00\Desktop\ASD_data\ASD\1101_ASY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1111_KJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1113_LJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1321_KSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1332_LJM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1542_KYL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1543_BYS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1563_CYS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1659_YHS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1692_CMK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1694_LDW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1712_SHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1727_SYS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1734_PJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1736_KSJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1746_YDK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1751_CYS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1787_CWJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1812_PMJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1820_PSY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1835_SHM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1856_CJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1888_ASY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1901_WHS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\1914_KMS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2026_CJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2038_KMS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2054_LKH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2071_LWH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2105_CHW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2126_SES\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2157_WJY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2239_KHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2247_KBY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2261_KKB\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2262_ASY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2288_CWS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2304_HLA\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2322_KSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2333_CSW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2356_KHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2383_PSY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2442_SJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2478_CHK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2524_KSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2540_PDK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2600_HJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2610_PHY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2626_CYW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2654_PYN\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2659_SJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2711_CYR\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2719_HKY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2733_PSB\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2768_LKM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2780_KHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2784_KMS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2793_LDY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2811_HTS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2819_KSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2853_LSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2886_LSM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2898_JHS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2899_LHN\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2912_PKL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2922_JJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2932_LSC\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2936_SYW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\2983_KMH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3009_PCH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3011_LSW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3031_SEH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3044_LJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3070_CYY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3127_KDH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3207_KHK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3341_SCW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3347_KTW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3401_MJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3420_CSY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3488_KSW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3516_LSY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3519_SMK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3522_HSO\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3563_LYS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3565_LYR\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3608_KBJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3628_YSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3635_KSM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3662_KYB\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3672_YSB\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3685_SYH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3722_SNRB\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3723_KRH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3744_BSW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\3951_CAY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\398_LJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4021_SSY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4026_KBM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4029_LSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4038_JKH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4043_KYR\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4044_SYJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4047_JKH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4067_PSW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4082_PJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4088_LCY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4099_JHW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4109_UDM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4134_SMJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4140_LHM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4154_KYS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4156_LDK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4157_KSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4184_PHM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4195_NYJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4204_SYJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4214_PJS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4224_YIS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4235_LSJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4242_LHY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4259_PSY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4270_CAI\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\427_LSA\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4280_PJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4283_CYW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4302_CHE\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4312_KYB\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4323_KYC\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4355_YJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4372_KSJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\438KMJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4396_KDW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4464_LHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4478_5_SJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4543_KJI\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4586_JYW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4600_LJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4618_KKH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4655_HJA\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4681_PSH_DL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4696_LSY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4704_SOY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4740_KDH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4753_KHK_DL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4773_DY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4787_ODE\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4804_KHN_DL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4806_KWK_DL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4827_SYJ_DL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4887_JBY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4890_LSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4907_HJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4916_SJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4925_KJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4951_KHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4954_LYJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\495_KDY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4994_KHM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\4997_KMH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\502_CJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\510_CSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5129_LHS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5139_PJS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5141_JHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5169_LDO\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5249_KDH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5253_USJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5274_OJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5282_OYR\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5296_KTY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5334_HSM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5338_KMJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5345_KTH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\5347_KEH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\537_PMJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\544_KSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\571_KJY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\592_LHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\622_HYJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\633_CSW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\652_LSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\653_LJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\780_OSL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\821_LSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\838_KHW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\858_PSY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\903_LJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\955_JSM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\972_HHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-05_PDJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-07_JYC\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-107_PJS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-111_PCW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-13_YSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-174_alexander\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-175_MKH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-234_JJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-238_KSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-240_KDK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-73_JWK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s4-97_PHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\s6-14_PHW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\1040_PSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\1084_CJS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\1665_LJY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\1825_HSJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\1928_HDE\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\1982_LCH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\2027_PCY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\2039_CMK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\2235_LSJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\2513_KYW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\2742_OYK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\2909_KDE\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\2917_JHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3002_KKW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3243_KKE\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3356_AIH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3390_PSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3415_PCA\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3472_MJY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3520_PYK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3525_BJY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3650_OYK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3706_LYJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3834_HJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3864_PSJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3972_LMS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3979_LSJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\3993_PSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\425_KAY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\4329_KMJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\4440_SYS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\4623_RJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\4629_PDAN\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\4702_KHR\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\4803_MTM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\5190_JSA\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\536_KMS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\569_KJW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\5776_LSM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\5789_JRO\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\5863_KYJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\5933_MHMD\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\5945_PEW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\638_SSA\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\716_JYW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\733_WJA\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\736_SYT\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\779_CHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\876_KBJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\s4-102\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\s4-266\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\s4-282\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\s4-29\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\s4-31\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\s4-326\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\s4-67\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\s4-98\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\s6-78_SHJ\aNew\MAGIC_T2\

# %% [markdown]
# # 3. Make Label

# %%
label=np.array([1]*203+[0]*(261-203), dtype=np.int64)

# %%
print(len(label))
# Out:
# 261

# %%
n=np.unique(label, axis=0)
n=n.shape[0]

label=np.eye(n)[label]
print(n)
# Out:
# 2

# %% [markdown]
# # 4. Divide Data path

# %% [markdown]
# Fix Test set for 20

# %%
test_asd='C:\\Users\\PC00\\Desktop\\ASD_data\\ASD\\Test\\'
test_control='C:\\Users\\PC00\\Desktop\\ASD_data\\CONTROL\\Test\\'

test_asd_p=os.listdir(test_asd)
test_control_p=os.listdir(test_control)

#MRI_image=['SPGR_P','MAGIC_T2']
MRI_image=['MAGIC_T2']
test_image_path=[]

for name in test_asd_p:
    path=''
    for image in MRI_image:
        path=test_asd+name+'\\'+'aNew'+'\\'
        path=path+image+'\\'
        test_image_path.append(path)
print("Test ASD Image Data : " , len(test_image_path)) 
for name in test_control_p:
    path=''
    for image in MRI_image:
        path=test_control+name+'\\'+'aNew'+'\\'
        path=path+image+'\\'
        test_image_path.append(path)
        
print("Test ASD+TC Image Data : " ,len(test_image_path))
# Out:
# Test ASD Image Data :  10
# Test ASD+TC Image Data :  20

# %%
for p in test_image_path:
    print(p)
# Out:
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\4837_KDK_DL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\4838_KKW_DL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\4839_PRK_DL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\4859_PJH_DL\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\4881_JWJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\5010_PHS\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\5023_PDK\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\5036_HKM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\5102_KMJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\ASD\Test\5115_HW\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\4371_SHJ\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\4582_MSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\4808_KTH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\4917_JSO\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\4931_LSY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\5158_KJH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\5301_KKY\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\5341_KSM\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\5533_BSH\aNew\MAGIC_T2\
# C:\Users\PC00\Desktop\ASD_data\CONTROL\Test\5660_KSY\aNew\MAGIC_T2\

# %%
test_label=np.array([1]*10+[0]*10, dtype=np.int64)

# %%
print(len(test_label))
# Out:
# 20

# %%
n=np.unique(test_label, axis=0)
n=n.shape[0]

test_label=np.eye(n)[test_label]
print(n)
# Out:
# 2

# %% [markdown]
# Train : Val = 0.8 : 0.2

# %%
train_path, val_path, train_label, val_label=train_test_split(all_image_path, label, test_size=0.3, random_state=CFG['SEED'])

# %%
print(len(train_path), len(val_path), len(train_label), len(val_label))
# Out:
# 182 79 182 79

# %%
train_asd=0
train_tc=0
for path in train_path:
    if 'CONTROL' in path:
        train_tc+=1
    
train_asd=len(train_path)-train_tc      
print("Train ASD : ", train_asd)
print("Train TC : ", train_tc)
# Out:
# Train ASD :  142
# Train TC :  40

# %%
val_asd=0
val_tc=0
for path in val_path:
    if 'CONTROL' in path:
        val_tc+=1
    
val_asd=len(val_path)-val_tc      
print("Val ASD : ", val_asd)
print("Val TC : ", val_tc)
# Out:
# Val ASD :  61
# Val TC :  18

# %% [markdown]
# # 5. Transform and augmentation

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Resize

# %%
pad_image=[[0]*256]*256

# %%
def T1_resize(img_volume, plus_image):
    #(256, 256, 188)
    
    want_channel=188
    original_channel=img_volume.shape[0]
    difference=abs(want_channel-original_channel)
  
    #차이가 짝수이면
    if difference==0:
        return img_volume
    else:
        img_volume=list(img_volume)
        if difference%2==0:
            #front & behind
            for _ in range(difference//2):
                img_volume.insert(0, plus_image)
                img_volume.insert(len(img_volume), plus_image)
                
            return np.array(img_volume)
        
        else:
            #front
            for _ in range(difference//2):
                img_volume.insert(0, plus_image)
            #behind    
            for _ in range(difference//2+1):
                img_volume.insert(len(img_volume), plus_image)
                
            return np.array(img_volume)

# %%
def T2_resize(img_volume, plus_image):
    #(256, 256, 34)
    
    want_channel=34
    original_channel=img_volume.shape[0]
    difference=abs(want_channel-original_channel)
  
    if difference==0:
        return img_volume
    else:
        img_volume=list(img_volume)
        #차이가 짝수이면
        if difference%2==0:
            #front & behind
            for _ in range(difference//2):
                img_volume.insert(0, plus_image)
                img_volume.insert(len(img_volume), plus_image)
                
            return np.array(img_volume)
        
        else:
            #front
            for _ in range(difference//2):
                img_volume.insert(0, plus_image)
            #behind    
            for _ in range(difference//2+1):
                img_volume.insert(len(img_volume), plus_image)
                
            return np.array(img_volume)

# %% [markdown]
# ### cropping

# %%
def T1_crop(img_volume):
    area=(25, 45, 215, 210)
    img_crop_volume=[]
    for i in range(img_volume.shape[0]):
        img=img_volume[i]
    
        img=Image.fromarray(np.uint16(img))

        img=img.crop(area)
        
        img=np.array(img)
        img=list(img)
        img_crop_volume.append(img)
  
    img_crop_volume=np.array(img_crop_volume)
    return img_crop_volume

# %%
def T2_crop(img_volume):
    area=(40, 20, 225, 225)
    img_crop_volume=[]
    for i in range(img_volume.shape[0]):
        img=img_volume[i]
    
        img=Image.fromarray(np.uint16(img))

        img=img.crop(area)
        
        img=np.array(img)
        img=list(img)
        img_crop_volume.append(img)
  
    img_crop_volume=np.array(img_crop_volume)
    return img_crop_volume

# %% [markdown]
# ### MinMaxScaler

# %%
class MinMaxScaler3D(MinMaxScaler):
    def fit_transform(self, X,y=None):
        x=np.reshape(X, newshape=(X.shape[0]*X.shape[1], X.shape[2]))
        return np.reshape(super().fit_transform(x, y=y), newshape=X.shape)

# %%
scaler = MinMaxScaler3D()

# %% [markdown]
# ## Augmentation

# %% [markdown]
# # 6. Get Image from data path

# %% [markdown]
# Convert to numpy (dicom -> numpy)

# %%
def convert_to_numpy(sitk_volume, size):
    """convert sitk image to numpy volume"""
    img_volume = sitk.GetArrayFromImage(sitk_volume)
    img_volume = img_volume.transpose(2,1,0)
    #print(img_volume.shape)
    if img_volume.shape[0]!=CFG['Image_Size']:
        img_volume = cv2.resize(img_volume, dsize=(CFG['Image_Size'], CFG['Image_Size']))
    
    #img_volume = img_volume.transpose(1,2,0)
    
    return img_volume

# %%
def get_image(path):
    reader=sitk.ImageSeriesReader()
    dicom_names=reader.GetGDCMSeriesFileNames(path)
    
    #print("Number of Series : ", len(dicom_names))
    
    reader.SetFileNames(dicom_names)
    
    image=reader.Execute()
    size=image.GetSize()
    #print("Original size of series : ", size[0], size[1], size[2])
    img_volume=convert_to_numpy(image, size)
    
    img_volume=img_volume.transpose(2,1,0)
    
    if 'SPGR_P' in path:
        img_volume=T1_resize(img_volume, pad_image)
        img_volume=T1_crop(img_volume)
    elif 'MAGIC_T2' in path:
        img_volume=T2_resize(img_volume, pad_image)
        img_volume=T2_crop(img_volume)
    #print("Convert size of series : ", img_volume.shape[0], img_volume.shape[1], img_volume.shape[2])
    img_volume = scaler.fit_transform(img_volume)
    return img_volume

# %% [markdown]
# # 7. CustomDataset

# %%
#T1+T2
class CustomDataset(Dataset):
    def __init__(self, path,labels, transforms=None):
        self.path=path
        self.labels=torch.from_numpy(labels)
        self.transforms=transforms
        
    def __getitem__(self, idx):
        #add label
        state=self.labels[idx]
        state=state.cuda()
        
        image=get_image(self.path[idx])
        image=np.array(image, dtype=np.int64)
        image=torch.from_numpy(image)
        
        image=torch.reshape(image,(1,image.shape[0], image.shape[1], image.shape[2]))
        
        if self.transforms:
            image = self.transforms(image)
        
        image=image.cuda()
        
        return image, state
        
    def __len__(self):
        return len(self.labels)

# %%
train_data=CustomDataset(train_path, train_label)
val_data=CustomDataset(val_path, val_label)

test_data=CustomDataset(test_image_path, test_label) # 나중에 augmentation할 때 적용 하면 안됨

# %%
n=random.randint(0,len(train_label))
print(n)
# Out:
# 163

# %%
train_data.__getitem__(n)[0].shape
# Out:
# torch.Size([1, 34, 205, 185])

# %%
train_dataloader=DataLoader(train_data, batch_size=CFG['BATCH_SIZE'],shuffle=True)
validation_dataloader=DataLoader(val_data, batch_size=CFG['BATCH_SIZE'], shuffle=True)
test_dataloader=DataLoader(test_data, batch_size=CFG['BATCH_SIZE'],shuffle=True)

# %%
train_features, train_labels=next(iter(train_dataloader))

# %% [markdown]
# # 8. Model

# %% [markdown]
# ## 3D CSResNet Model = CS Block + 3D ResNet Model

# %% [markdown]
# ## CS Block
# Channel block + spatial block

# %%
class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.size(0), -1)

class ChannelGate(nn.Module):
    def __init__(self, gate_channels, reduction_ratio=16, pool_types=['avg','max']):
        super(ChannelGate, self).__init__()
        self.gate_channels=gate_channels
        self.mlp=nn.Sequential(
                        Flatten(),
                        nn.Linear(gate_channels, gate_channels // reduction_ratio),
                        nn.ReLU(),
                        nn.Linear(gate_channels // reduction_ratio, gate_channels)
        )
        self.pool_types=pool_types
        
    def forward(self, x):
        channel_att_sum=None
        #print("Input of Channel gate shape : ", x.size(0), x.size(1), x.size(2), x.size(3)) # 8 64 17 64 64
        for pool_type in self.pool_types:
            if pool_type=='avg':
                avg_pool = F.avg_pool3d( x, (x.size(2), x.size(3), x.size(4)), stride=(x.size(2), x.size(3), x.size(4)))
                channel_att_raw = self.mlp( avg_pool )
            elif pool_type=='max':
                max_pool = F.max_pool3d( x, (x.size(2), x.size(3), x.size(4)), stride=(x.size(2), x.size(3), x.size(4)))
                channel_att_raw = self.mlp( max_pool )
            elif pool_type=='lp':
                lp_pool = F.lp_pool3d( x, (x.size(2), x.size(3), x.size(4)), stride=(x.size(2), x.size(3), x.size(4)))
                channel_att_raw = self.mlp( lp_pool )
                
            if channel_att_sum is None:
                channel_att_sum=channel_att_raw
            else:
                channel_att_sum=channel_att_sum+channel_att_raw
                
        scale = F.sigmoid(channel_att_sum).unsqueeze(2).unsqueeze(3).unsqueeze(4).expand_as(x)
        return x*scale

# %%
class BasicConv(nn.Module):
    def __init__(self, in_planes, out_planes, kernel_size, stride=1, padding=0, dilation=1, groups=1, relu=True, bn=True, bias=False):
        super(BasicConv, self).__init__()
        self.out_channels = out_planes
        self.conv = nn.Conv3d(in_planes, out_planes, kernel_size=kernel_size, stride=stride, padding=padding, dilation=dilation, groups=groups, bias=bias)
        self.bn = nn.BatchNorm3d(out_planes,eps=1e-5, momentum=0.01, affine=True) if bn else None
        self.relu = nn.ReLU() if relu else None

    def forward(self, x):
        x = self.conv(x)
        if self.bn is not None:
            x = self.bn(x)
        if self.relu is not None:
            x = self.relu(x)
        return x

# %%
class ChannelPool(nn.Module):
    def forward(self, x):
        return torch.cat( (torch.max(x,1)[0].unsqueeze(1), torch.mean(x,1).unsqueeze(1)), dim=1 )

class SpatialGate(nn.Module):
    def __init__(self):
        super(SpatialGate, self).__init__()
        kernel_size=7
        self.compress=ChannelPool()
        self.spatial=BasicConv(2,1, kernel_size, stride=1, padding=(kernel_size-1)//2, relu=False)
        
    def forward(self, x):
        x_compress=self.compress(x)
        x_out=self.spatial(x_compress)
        scale=F.sigmoid(x_out) #broadcasting
        return x*scale

# %%
class CBAM(nn.Module):
    def __init__(self, gate_channels, reduction_ratio=16, pool_types=['avg','max'], no_spatial=False):
        super(CBAM, self).__init__()
        self.ChannelGate=ChannelGate(gate_channels, reduction_ratio, pool_types)
        self.no_spatial=no_spatial
        if not no_spatial:
            self.SpatialGate=SpatialGate()
            
    def forward(self, x):
        x_out=self.ChannelGate(x)
        if not self.no_spatial:
            x_out=self.SpatialGate(x_out)
            
        return x_out

# %% [markdown]
# ## 3D ResNet

# %%
def get_inplanes():
    return [64, 128, 256, 512]

def conv3x3x3(in_planes, out_planes, stride=1):
    return nn.Conv3d(in_planes,
                     out_planes,
                     kernel_size=3,
                     stride=stride,
                     padding=1,
                     bias=False)

def conv1x1x1(in_planes, out_planes, stride=1):
    return nn.Conv3d(in_planes,
                     out_planes,
                     kernel_size=1,
                     stride=stride,
                     bias=False)

class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1, downsample=None, CBAM_use=False):
        super().__init__()

        self.conv1 = conv3x3x3(in_planes, planes, stride)
        self.bn1 = nn.BatchNorm3d(planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = conv3x3x3(planes, planes)
        self.bn2 = nn.BatchNorm3d(planes)
        self.downsample = downsample
        self.stride = stride
        
        if CBAM:
            self.cbam=CBAM(planes, 16)
        else:
            self.cbam=None

    def forward(self, x):
        residual = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        if self.downsample is not None:
            residual = self.downsample(x)
            
        if not self.cbam is None:
            out=self.cbam(out)

        out += residual
        out = self.relu(out)
        
        return out

# %%
class ResNet18(nn.Module):
    def __init__(self, 
                 block, #Basicblock
                 layers, #[2,2,2,2]
                 block_inplanes, #[64, 128, 256, 512]
                 in_channels, #1
                 out_channels, #64
                 shortcut_type='B',
                 att_type=None,
                 stride=2, 
                 n_classes=2): #1, 64
        super().__init__()

        self.in_planes=block_inplanes[0]
        self.no_max_pool=False

        self.conv1=nn.Conv3d(in_channels, self.in_planes, kernel_size=(7,7,7), stride=(1,2,2), padding=(7//2,3,3), bias=False)
        self.bn1=nn.BatchNorm3d(out_channels)
        self.relu=nn.ReLU(inplace=True) #? -> 기존의 데이터를 연산의 결괏값으로 대체하는 것
        self.maxpool=nn.MaxPool3d(kernel_size=3, stride=2, padding=1)
        
        self.layer1=self._make_layer(block, block_inplanes[0], layers[0], shortcut_type)
        self.layer2=self._make_layer(block, block_inplanes[1], layers[1], shortcut_type, stride=2)
        self.layer3=self._make_layer(block, block_inplanes[2], layers[2], shortcut_type, stride=2)
        self.layer4=self._make_layer(block, block_inplanes[3], layers[3], shortcut_type, stride=2)

        self.avgpool = nn.AdaptiveAvgPool3d((1,1,1))
        self.fc=nn.Linear(block_inplanes[3]*block.expansion, n_classes)
        self.sigmoid=torch.nn.Sigmoid()
        self.dropout=nn.Dropout(0.2)
        
        if att_type=='BAM':
            self.bam1=BAM(64*block.expansion)
            self.bam2=BAM(128*block.expansion)
            self.bam3=BAM(256*block.expansion)
        else:
            self.bam1, self.bam2, self.bam3=None, None, None
        
        for m in self.modules():
            if isinstance(m, nn.Conv3d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu') # He initialization
            elif isinstance(m, nn.BatchNorm3d):
                nn.init.constant_(m.weight, 1) # 초기값  설정
                nn.init.constant_(m.bias, 0)

    def _make_layer(self, block, planes, blocks, shortcut_type, stride=1):
        downsample=None
        if stride!=1 or self.in_planes != planes*block.expansion:
            if shortcut_type=='A':
                downsample=partial(self._dwonsample_basic_block, planes=planes * block.expansion, stride=stride)
            else:
                downsample=nn.Sequential(
                    conv1x1x1(self.in_planes, planes*block.expansion, stride),
                    nn.BatchNorm3d(planes*block.expansion),
                )

        layers=[]
        layers.append(
            block(in_planes=self.in_planes, planes=planes, stride=stride, downsample=downsample, CBAM_use=True),
        )
        

        self.in_planes=planes*block.expansion
        for i in range(1, blocks):
            layers.append(block(self.in_planes, planes, CBAM_use=True))

        return nn.Sequential(*layers)

    def forward(self, x):
        x=self.conv1(x)
        x=self.bn1(x)
        x=self.relu(x)
        if not self.no_max_pool:
            x=self.maxpool(x)

        x=self.layer1(x)
        x=self.dropout(x)
        x=self.layer2(x)
        x=self.dropout(x)
        x=self.layer3(x)
        x=self.dropout(x)
        x=self.layer4(x)
        x=self.dropout(x)

        x=self.avgpool(x)

        x=x.view(x.size(0), -1)
        x=self.fc(x)
        x=self.sigmoid(x)
        #print('out : ', x.shape)
        return x

# %%
model=ResNet18(BasicBlock, [2,2,2,2], get_inplanes(), 1, 64)

# %%
model=model.to(device)

# %%
model
# Out:
# ResNet18(
#   (conv1): Conv3d(1, 64, kernel_size=(7, 7, 7), stride=(1, 2, 2), padding=(3, 3, 3), bias=False)
#   (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=64, out_features=4, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=4, out_features=64, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=64, out_features=4, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=4, out_features=64, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv3d(64, 128, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=128, out_features=8, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=8, out_features=128, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=128, out_features=8, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=8, out_features=128, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv3d(128, 256, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=256, out_features=16, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=16, out_features=256, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=256, out_features=16, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=16, out_features=256, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=512, out_features=32, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=32, out_features=512, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=512, out_features=32, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=32, out_features=512, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool3d(output_size=(1, 1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 33,255,610 trainable parameters

# %% [markdown]
# # 9. Define Loss Function and Optimizer

# %%
class FocalLoss(nn.Module):
    def __init__(self, gamma=0, alpha=None, size_average=True):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        if isinstance(alpha,(float,int)): self.alpha = torch.Tensor([alpha,1-alpha])
        if isinstance(alpha,list): self.alpha = torch.Tensor(alpha)
        self.size_average = size_average

    def forward(self, input, target):
        if input.dim()>2:
            input = input.view(input.size(0),input.size(1),-1)  # N,C,H,W => N,C,H*W
            input = input.transpose(1,2)    # N,C,H*W => N,H*W,C
            input = input.contiguous().view(-1,input.size(2))   # N,H*W,C => N*H*W,C
        target = target.view(-1,1)

        logpt = F.log_softmax(input)
        print(type(logpt), logpt.shape)
        print(logpt)
        logpt = logpt.gather(1,target)
        logpt = logpt.view(-1)
        pt = Variable(logpt.data.exp())

        if self.alpha is not None:
            if self.alpha.type()!=input.data.type():
                self.alpha = self.alpha.type_as(input.data)
            at = self.alpha.gather(0,target.data.view(-1))
            logpt = logpt * Variable(at)

        loss = -1 * (1-pt)**self.gamma * logpt
        if self.size_average: return loss.mean()
        else: return loss.sum()

# %%
loss_fn=nn.CrossEntropyLoss().to(device)
optimizer=torch.optim.Adam(model.parameters(), 
                           lr=CFG['Learning_rate'], 
                           betas=(CFG['beta_1'], CFG['beta_2']), 
                           eps=CFG['eps'], 
                           weight_decay=CFG['weight_decay'])

# %% [markdown]
# # 10. EarlyStopping

# %% [markdown]
# # 11. KFold

# %% [markdown]
# # 12. Train & Validation

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    
    size=len(dataloader.dataset)
    print("데이터 사이즈 : ", size)
    
    train_loss, correct=0,0
    
    model.train()
    
    #autograd engine(gradient를 계산해주는 context)을 비활성화 시켜 필요한 메모리를 줄여주고 연산속도 증가
    
    for batch, (X,y) in (enumerate((dataloader))):
        #print(type(X), type(y))
        #y=y.to(device)
        X=Variable(X.to(device).float())
        y=Variable(y.to(device).float())
        pred=model(X)
        #print(pred)
        #print(y)
        loss=loss_fn(pred,y)
        train_loss+=loss.item()
        correct+=(pred.argmax(1)==y.argmax(1)).type(torch.float).sum().item()
        #print('batch : ', batch)
        #print('loss : ', loss)
        #print('pred : ', pred)
        #역전파
        optimizer.zero_grad() #gradient를 0으로 초기화
        loss.requires_grad_(True)
        loss.backward() #비용 함수를 미분하여 gradient 계산
        optimizer.step() #update weight and bias
        
        if batch%10==0:
            loss, current=loss.item(), batch*len(X)
            print(f"Batch {batch} loss : {loss:>7f} [{current:>5d}/{size:>5d}]")  
        
    train_loss/=size
    correct/=size
    
    print(f"Train\n Accuracy : {(100*correct):>0.1f}%, Avg Loss : {train_loss:>8f}\n")
    return train_loss, correct

# %%
def val_loop(dataloader, model, loss_fn):
    size=len(dataloader.dataset)
    
    num_batches=len(dataloader)
    val_loss, correct=0,0
    
    model.eval()
    with torch.no_grad():
        for X,y in dataloader:
            X=Variable(X.to(device).float())
            #print(X.shape)
            y=Variable(y.to(device).float())
            pred=model(X)
            #print(pred.shape)
            val_loss+=loss_fn(pred, y).item()
            correct+=(pred.argmax(1)==y.argmax(1)).type(torch.float).sum().item()
            
    val_loss/=num_batches
    correct/=size
    
    print(f"Validation\n Accuracy : {(100*correct):>0.1f}%, Avg Loss : {val_loss:>8f}\n")
    return val_loss, correct

# %%
train_loss_info=[]
train_acc_info=[]

val_loss_info=[]
val_acc_info=[]

start=time.time()

for t in range(CFG['EPOCHS']):
    print(f"Epoch {t+1}\n-------------------------------------------")
    start_epoch=time.time()
    train_loss, train_acc=train_loop(train_dataloader, model, loss_fn, optimizer)
    train_loss_info.append(train_loss)
    train_acc_info.append(train_acc)
    
    val_loss, val_acc=val_loop(validation_dataloader, model, loss_fn)
    val_loss_info.append(val_loss)
    val_acc_info.append(val_acc)
    
    end_epoch=time.time()
    print(f"Epcoh time : {(end_epoch-start_epoch)//60}분 {(end_epoch-start_epoch)%60} 초")
    print(f"Epoch {t+1} End\n-------------------------------------------")
    print()
    
end=time.time()

print("Epoch 걸린 시간 : ", (end-start)//60, " 분", (end-start)%60, " 초")
# Out:
# Epoch 1
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.694751 [    0/  182]
# Batch 10 loss : 0.481307 [   80/  182]
# Batch 20 loss : 0.430099 [  160/  182]
# Train
#  Accuracy : 75.3%, Avg Loss : 0.070256
#
# Validation
#  Accuracy : 77.2%, Avg Loss : 0.584231
#
# Epcoh time : 0.0분 55.896207332611084 초
# Epoch 1 End
# -------------------------------------------
#
# Epoch 2
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.665909 [    0/  182]
# Batch 10 loss : 0.676250 [   80/  182]
# Batch 20 loss : 0.325680 [  160/  182]
# Train
#  Accuracy : 78.0%, Avg Loss : 0.066671
#
# Validation
#  Accuracy : 77.2%, Avg Loss : 0.621375
#
# Epcoh time : 0.0분 45.74912428855896 초
# Epoch 2 End
# -------------------------------------------
#
# Epoch 3
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.632336 [    0/  182]
# Batch 10 loss : 0.431134 [   80/  182]
# Batch 20 loss : 0.398050 [  160/  182]
# Train
#  Accuracy : 79.1%, Avg Loss : 0.063659
#
# Validation
#  Accuracy : 22.8%, Avg Loss : 0.853230
#
# Epcoh time : 0.0분 47.29806709289551 초
# Epoch 3 End
# -------------------------------------------
#
# Epoch 4
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.539638 [    0/  182]
# Batch 10 loss : 0.488837 [   80/  182]
# Batch 20 loss : 0.541049 [  160/  182]
# Train
#  Accuracy : 86.8%, Avg Loss : 0.057297
#
# Validation
#  Accuracy : 24.1%, Avg Loss : 1.041963
#
# Epcoh time : 0.0분 46.83742809295654 초
# Epoch 4 End
# -------------------------------------------
#
# Epoch 5
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.443691 [    0/  182]
# Batch 10 loss : 0.326175 [   80/  182]
# Batch 20 loss : 0.322369 [  160/  182]
# Train
#  Accuracy : 93.4%, Avg Loss : 0.050004
#
# Validation
#  Accuracy : 24.1%, Avg Loss : 1.063147
#
# Epcoh time : 0.0분 45.84722328186035 초
# Epoch 5 End
# -------------------------------------------
#
# Epoch 6
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.701084 [    0/  182]
# Batch 10 loss : 0.367177 [   80/  182]
# Batch 20 loss : 0.572274 [  160/  182]
# Train
#  Accuracy : 91.8%, Avg Loss : 0.049927
#
# Validation
#  Accuracy : 29.1%, Avg Loss : 1.016376
#
# Epcoh time : 0.0분 45.94222807884216 초
# Epoch 6 End
# -------------------------------------------
#
# Epoch 7
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.339822 [    0/  182]
# Batch 10 loss : 0.430762 [   80/  182]
# Batch 20 loss : 0.424913 [  160/  182]
# Train
#  Accuracy : 93.4%, Avg Loss : 0.047863
#
# Validation
#  Accuracy : 72.2%, Avg Loss : 0.611218
#
# Epcoh time : 0.0분 45.982146978378296 초
# Epoch 7 End
# -------------------------------------------
#
# Epoch 8
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.384699 [    0/  182]
# Batch 10 loss : 0.548649 [   80/  182]
# Batch 20 loss : 0.320180 [  160/  182]
# Train
#  Accuracy : 91.2%, Avg Loss : 0.051116
#
# Validation
#  Accuracy : 75.9%, Avg Loss : 0.564922
#
# Epcoh time : 0.0분 45.69608545303345 초
# Epoch 8 End
# -------------------------------------------
#
# Epoch 9
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.325216 [    0/  182]
# Batch 10 loss : 0.421296 [   80/  182]
# Batch 20 loss : 0.313587 [  160/  182]
# Train
#  Accuracy : 95.6%, Avg Loss : 0.045836
#
# Validation
#  Accuracy : 60.8%, Avg Loss : 0.698311
#
# Epcoh time : 0.0분 46.101967096328735 초
# Epoch 9 End
# -------------------------------------------
#
# Epoch 10
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.438496 [    0/  182]
# Batch 10 loss : 0.313698 [   80/  182]
# Batch 20 loss : 0.318159 [  160/  182]
# Train
#  Accuracy : 94.5%, Avg Loss : 0.045840
#
# Validation
#  Accuracy : 29.1%, Avg Loss : 1.009673
#
# Epcoh time : 0.0분 46.69857883453369 초
# Epoch 10 End
# -------------------------------------------
#
# Epoch 11
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.333773 [    0/  182]
# Batch 10 loss : 0.325216 [   80/  182]
# Batch 20 loss : 0.570825 [  160/  182]
# Train
#  Accuracy : 94.5%, Avg Loss : 0.045863
#
# Validation
#  Accuracy : 29.1%, Avg Loss : 1.002254
#
# Epcoh time : 0.0분 46.55164122581482 초
# Epoch 11 End
# -------------------------------------------
#
# Epoch 12
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313867 [    0/  182]
# Batch 10 loss : 0.427819 [   80/  182]
# Batch 20 loss : 0.425873 [  160/  182]
# Train
#  Accuracy : 94.5%, Avg Loss : 0.046578
#
# Validation
#  Accuracy : 54.4%, Avg Loss : 0.748233
#
# Epcoh time : 0.0분 46.01566410064697 초
# Epoch 12 End
# -------------------------------------------
#
# Epoch 13
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.442044 [    0/  182]
# Batch 10 loss : 0.315272 [   80/  182]
# Batch 20 loss : 0.400743 [  160/  182]
# Train
#  Accuracy : 95.6%, Avg Loss : 0.045082
#
# Validation
#  Accuracy : 51.9%, Avg Loss : 0.789076
#
# Epcoh time : 0.0분 46.103819847106934 초
# Epoch 13 End
# -------------------------------------------
#
# Epoch 14
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313738 [    0/  182]
# Batch 10 loss : 0.313394 [   80/  182]
# Batch 20 loss : 0.458687 [  160/  182]
# Train
#  Accuracy : 97.3%, Avg Loss : 0.043524
#
# Validation
#  Accuracy : 30.4%, Avg Loss : 0.993786
#
# Epcoh time : 0.0분 44.93525815010071 초
# Epoch 14 End
# -------------------------------------------
#
# Epoch 15
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.314339 [    0/  182]
# Batch 10 loss : 0.313472 [   80/  182]
# Batch 20 loss : 0.313742 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.041912
#
# Validation
#  Accuracy : 30.4%, Avg Loss : 0.982541
#
# Epcoh time : 0.0분 44.95187425613403 초
# Epoch 15 End
# -------------------------------------------
#
# Epoch 16
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313553 [    0/  182]
# Batch 10 loss : 0.436426 [   80/  182]
# Batch 20 loss : 0.318466 [  160/  182]
# Train
#  Accuracy : 95.6%, Avg Loss : 0.044554
#
# Validation
#  Accuracy : 39.2%, Avg Loss : 0.899342
#
# Epcoh time : 0.0분 45.43706560134888 초
# Epoch 16 End
# -------------------------------------------
#
# Epoch 17
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.380966 [    0/  182]
# Batch 10 loss : 0.383280 [   80/  182]
# Batch 20 loss : 0.325312 [  160/  182]
# Train
#  Accuracy : 96.2%, Avg Loss : 0.044449
#
# Validation
#  Accuracy : 70.9%, Avg Loss : 0.590421
#
# Epcoh time : 0.0분 45.74236178398132 초
# Epoch 17 End
# -------------------------------------------
#
# Epoch 18
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.316005 [    0/  182]
# Batch 10 loss : 0.313579 [   80/  182]
# Batch 20 loss : 0.313376 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041851
#
# Validation
#  Accuracy : 44.3%, Avg Loss : 0.819797
#
# Epcoh time : 0.0분 45.82575464248657 초
# Epoch 18 End
# -------------------------------------------
#
# Epoch 19
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.314016 [    0/  182]
# Batch 10 loss : 0.313421 [   80/  182]
# Batch 20 loss : 0.321183 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040444
#
# Validation
#  Accuracy : 46.8%, Avg Loss : 0.825646
#
# Epcoh time : 0.0분 46.68489933013916 초
# Epoch 19 End
# -------------------------------------------
#
# Epoch 20
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313382 [    0/  182]
# Batch 10 loss : 0.314843 [   80/  182]
# Batch 20 loss : 0.478197 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.041555
#
# Validation
#  Accuracy : 34.2%, Avg Loss : 0.954737
#
# Epcoh time : 0.0분 46.174846172332764 초
# Epoch 20 End
# -------------------------------------------
#
# Epoch 21
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.314376 [    0/  182]
# Batch 10 loss : 0.314206 [   80/  182]
# Batch 20 loss : 0.314516 [  160/  182]
# Train
#  Accuracy : 96.2%, Avg Loss : 0.043592
#
# Validation
#  Accuracy : 32.9%, Avg Loss : 0.951395
#
# Epcoh time : 0.0분 45.84540843963623 초
# Epoch 21 End
# -------------------------------------------
#
# Epoch 22
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.408444 [    0/  182]
# Batch 10 loss : 0.325608 [   80/  182]
# Batch 20 loss : 0.459267 [  160/  182]
# Train
#  Accuracy : 97.3%, Avg Loss : 0.043420
#
# Validation
#  Accuracy : 26.6%, Avg Loss : 1.045143
#
# Epcoh time : 0.0분 45.67103719711304 초
# Epoch 22 End
# -------------------------------------------
#
# Epoch 23
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313782 [    0/  182]
# Batch 10 loss : 0.428836 [   80/  182]
# Batch 20 loss : 0.317116 [  160/  182]
# Train
#  Accuracy : 97.3%, Avg Loss : 0.042808
#
# Validation
#  Accuracy : 38.0%, Avg Loss : 0.902415
#
# Epcoh time : 0.0분 46.28391933441162 초
# Epoch 23 End
# -------------------------------------------
#
# Epoch 24
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313284 [    0/  182]
# Batch 10 loss : 0.322238 [   80/  182]
# Batch 20 loss : 0.313374 [  160/  182]
# Train
#  Accuracy : 95.6%, Avg Loss : 0.044977
#
# Validation
#  Accuracy : 58.2%, Avg Loss : 0.692766
#
# Epcoh time : 0.0분 45.7875759601593 초
# Epoch 24 End
# -------------------------------------------
#
# Epoch 25
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.316956 [    0/  182]
# Batch 10 loss : 0.313470 [   80/  182]
# Batch 20 loss : 0.319831 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041406
#
# Validation
#  Accuracy : 64.6%, Avg Loss : 0.622958
#
# Epcoh time : 0.0분 46.27339220046997 초
# Epoch 25 End
# -------------------------------------------
#
# Epoch 26
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.314275 [    0/  182]
# Batch 10 loss : 0.313279 [   80/  182]
# Batch 20 loss : 0.620513 [  160/  182]
# Train
#  Accuracy : 95.6%, Avg Loss : 0.044600
#
# Validation
#  Accuracy : 35.4%, Avg Loss : 0.947710
#
# Epcoh time : 0.0분 46.69615292549133 초
# Epoch 26 End
# -------------------------------------------
#
# Epoch 27
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313285 [    0/  182]
# Batch 10 loss : 0.313858 [   80/  182]
# Batch 20 loss : 0.443257 [  160/  182]
# Train
#  Accuracy : 94.0%, Avg Loss : 0.046477
#
# Validation
#  Accuracy : 78.5%, Avg Loss : 0.529026
#
# Epcoh time : 0.0분 45.65171432495117 초
# Epoch 27 End
# -------------------------------------------
#
# Epoch 28
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313358 [    0/  182]
# Batch 10 loss : 0.333262 [   80/  182]
# Batch 20 loss : 0.313353 [  160/  182]
# Train
#  Accuracy : 94.5%, Avg Loss : 0.045278
#
# Validation
#  Accuracy : 63.3%, Avg Loss : 0.663865
#
# Epcoh time : 0.0분 46.545881509780884 초
# Epoch 28 End
# -------------------------------------------
#
# Epoch 29
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313966 [    0/  182]
# Batch 10 loss : 0.313288 [   80/  182]
# Batch 20 loss : 0.313880 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041778
#
# Validation
#  Accuracy : 53.2%, Avg Loss : 0.765043
#
# Epcoh time : 0.0분 46.32253670692444 초
# Epoch 29 End
# -------------------------------------------
#
# Epoch 30
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.319478 [    0/  182]
# Batch 10 loss : 0.316639 [   80/  182]
# Batch 20 loss : 0.347534 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.042314
#
# Validation
#  Accuracy : 64.6%, Avg Loss : 0.657788
#
# Epcoh time : 0.0분 46.622560024261475 초
# Epoch 30 End
# -------------------------------------------
#
# Epoch 31
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.412746 [    0/  182]
# Batch 10 loss : 0.327192 [   80/  182]
# Batch 20 loss : 0.313346 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041517
#
# Validation
#  Accuracy : 32.9%, Avg Loss : 0.935200
#
# Epcoh time : 0.0분 46.14775896072388 초
# Epoch 31 End
# -------------------------------------------
#
# Epoch 32
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.315877 [    0/  182]
# Batch 10 loss : 0.314402 [   80/  182]
# Batch 20 loss : 0.313299 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040682
#
# Validation
#  Accuracy : 35.4%, Avg Loss : 0.950508
#
# Epcoh time : 0.0분 46.20553922653198 초
# Epoch 32 End
# -------------------------------------------
#
# Epoch 33
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.321478 [    0/  182]
# Batch 10 loss : 0.316201 [   80/  182]
# Batch 20 loss : 0.314194 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.041130
#
# Validation
#  Accuracy : 67.1%, Avg Loss : 0.629445
#
# Epcoh time : 0.0분 46.29885697364807 초
# Epoch 33 End
# -------------------------------------------
#
# Epoch 34
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313375 [    0/  182]
# Batch 10 loss : 0.431519 [   80/  182]
# Batch 20 loss : 0.316271 [  160/  182]
# Train
#  Accuracy : 97.3%, Avg Loss : 0.042981
#
# Validation
#  Accuracy : 32.9%, Avg Loss : 0.992514
#
# Epcoh time : 0.0분 46.999284744262695 초
# Epoch 34 End
# -------------------------------------------
#
# Epoch 35
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.331408 [    0/  182]
# Batch 10 loss : 0.314626 [   80/  182]
# Batch 20 loss : 0.313280 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.042257
#
# Validation
#  Accuracy : 72.2%, Avg Loss : 0.590552
#
# Epcoh time : 0.0분 46.5294394493103 초
# Epoch 35 End
# -------------------------------------------
#
# Epoch 36
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.358181 [    0/  182]
# Batch 10 loss : 0.313314 [   80/  182]
# Batch 20 loss : 0.314517 [  160/  182]
# Train
#  Accuracy : 97.8%, Avg Loss : 0.042495
#
# Validation
#  Accuracy : 31.6%, Avg Loss : 0.977976
#
# Epcoh time : 0.0분 47.176132678985596 초
# Epoch 36 End
# -------------------------------------------
#
# Epoch 37
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313313 [    0/  182]
# Batch 10 loss : 0.313286 [   80/  182]
# Batch 20 loss : 0.313715 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.040795
#
# Validation
#  Accuracy : 48.1%, Avg Loss : 0.826681
#
# Epcoh time : 0.0분 45.745617628097534 초
# Epoch 37 End
# -------------------------------------------
#
# Epoch 38
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.524600 [    0/  182]
# Batch 10 loss : 0.313617 [   80/  182]
# Batch 20 loss : 0.313352 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041891
#
# Validation
#  Accuracy : 44.3%, Avg Loss : 0.842844
#
# Epcoh time : 0.0분 45.19138288497925 초
# Epoch 38 End
# -------------------------------------------
#
# Epoch 39
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.314594 [    0/  182]
# Batch 10 loss : 0.313285 [   80/  182]
# Batch 20 loss : 0.313762 [  160/  182]
# Train
#  Accuracy : 97.8%, Avg Loss : 0.042412
#
# Validation
#  Accuracy : 44.3%, Avg Loss : 0.846391
#
# Epcoh time : 0.0분 45.56491303443909 초
# Epoch 39 End
# -------------------------------------------
#
# Epoch 40
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.314253 [    0/  182]
# Batch 10 loss : 0.316786 [   80/  182]
# Batch 20 loss : 0.313672 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039862
#
# Validation
#  Accuracy : 31.6%, Avg Loss : 0.942358
#
# Epcoh time : 0.0분 44.94522309303284 초
# Epoch 40 End
# -------------------------------------------
#
# Epoch 41
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313332 [    0/  182]
# Batch 10 loss : 0.353314 [   80/  182]
# Batch 20 loss : 0.314723 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041869
#
# Validation
#  Accuracy : 39.2%, Avg Loss : 0.870154
#
# Epcoh time : 0.0분 45.31708383560181 초
# Epoch 41 End
# -------------------------------------------
#
# Epoch 42
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.315861 [    0/  182]
# Batch 10 loss : 0.313324 [   80/  182]
# Batch 20 loss : 0.437244 [  160/  182]
# Train
#  Accuracy : 97.3%, Avg Loss : 0.043071
#
# Validation
#  Accuracy : 35.4%, Avg Loss : 0.918379
#
# Epcoh time : 0.0분 45.041629791259766 초
# Epoch 42 End
# -------------------------------------------
#
# Epoch 43
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313269 [    0/  182]
# Batch 10 loss : 0.322904 [   80/  182]
# Batch 20 loss : 0.313599 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041517
#
# Validation
#  Accuracy : 75.9%, Avg Loss : 0.557074
#
# Epcoh time : 0.0분 45.905059814453125 초
# Epoch 43 End
# -------------------------------------------
#
# Epoch 44
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313356 [    0/  182]
# Batch 10 loss : 0.318861 [   80/  182]
# Batch 20 loss : 0.313329 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041268
#
# Validation
#  Accuracy : 38.0%, Avg Loss : 0.902648
#
# Epcoh time : 0.0분 44.82418775558472 초
# Epoch 44 End
# -------------------------------------------
#
# Epoch 45
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313322 [    0/  182]
# Batch 10 loss : 0.318153 [   80/  182]
# Batch 20 loss : 0.316455 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039902
#
# Validation
#  Accuracy : 50.6%, Avg Loss : 0.768010
#
# Epcoh time : 0.0분 45.04833126068115 초
# Epoch 45 End
# -------------------------------------------
#
# Epoch 46
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.386828 [    0/  182]
# Batch 10 loss : 0.313279 [   80/  182]
# Batch 20 loss : 0.313302 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.040516
#
# Validation
#  Accuracy : 30.4%, Avg Loss : 0.971639
#
# Epcoh time : 0.0분 46.10176181793213 초
# Epoch 46 End
# -------------------------------------------
#
# Epoch 47
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.320929 [    0/  182]
# Batch 10 loss : 0.317936 [   80/  182]
# Batch 20 loss : 0.313277 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040482
#
# Validation
#  Accuracy : 40.5%, Avg Loss : 0.901651
#
# Epcoh time : 0.0분 46.82414937019348 초
# Epoch 47 End
# -------------------------------------------
#
# Epoch 48
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313289 [    0/  182]
# Batch 10 loss : 0.313849 [   80/  182]
# Batch 20 loss : 0.313312 [  160/  182]
# Train
#  Accuracy : 97.8%, Avg Loss : 0.042204
#
# Validation
#  Accuracy : 69.6%, Avg Loss : 0.589254
#
# Epcoh time : 0.0분 46.90298533439636 초
# Epoch 48 End
# -------------------------------------------
#
# Epoch 49
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313395 [    0/  182]
# Batch 10 loss : 0.314349 [   80/  182]
# Batch 20 loss : 0.313310 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.040856
#
# Validation
#  Accuracy : 68.4%, Avg Loss : 0.625674
#
# Epcoh time : 0.0분 45.55087924003601 초
# Epoch 49 End
# -------------------------------------------
#
# Epoch 50
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313264 [    0/  182]
# Batch 10 loss : 0.313263 [   80/  182]
# Batch 20 loss : 0.317088 [  160/  182]
# Train
#  Accuracy : 93.4%, Avg Loss : 0.047146
#
# Validation
#  Accuracy : 30.4%, Avg Loss : 1.006072
#
# Epcoh time : 0.0분 45.47714948654175 초
# Epoch 50 End
# -------------------------------------------
#
# Epoch 51
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.430142 [    0/  182]
# Batch 10 loss : 0.313744 [   80/  182]
# Batch 20 loss : 0.437710 [  160/  182]
# Train
#  Accuracy : 95.1%, Avg Loss : 0.045357
#
# Validation
#  Accuracy : 53.2%, Avg Loss : 0.727845
#
# Epcoh time : 0.0분 45.716774702072144 초
# Epoch 51 End
# -------------------------------------------
#
# Epoch 52
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.366910 [    0/  182]
# Batch 10 loss : 0.313592 [   80/  182]
# Batch 20 loss : 0.313394 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040349
#
# Validation
#  Accuracy : 38.0%, Avg Loss : 0.878142
#
# Epcoh time : 0.0분 45.89273643493652 초
# Epoch 52 End
# -------------------------------------------
#
# Epoch 53
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313361 [    0/  182]
# Batch 10 loss : 0.316824 [   80/  182]
# Batch 20 loss : 0.313270 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.040006
#
# Validation
#  Accuracy : 58.2%, Avg Loss : 0.710402
#
# Epcoh time : 0.0분 45.96500015258789 초
# Epoch 53 End
# -------------------------------------------
#
# Epoch 54
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313763 [    0/  182]
# Batch 10 loss : 0.313274 [   80/  182]
# Batch 20 loss : 0.313277 [  160/  182]
# Train
#  Accuracy : 97.8%, Avg Loss : 0.042034
#
# Validation
#  Accuracy : 31.6%, Avg Loss : 0.967552
#
# Epcoh time : 0.0분 46.44495224952698 초
# Epoch 54 End
# -------------------------------------------
#
# Epoch 55
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.394486 [    0/  182]
# Batch 10 loss : 0.313283 [   80/  182]
# Batch 20 loss : 0.313267 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.041550
#
# Validation
#  Accuracy : 63.3%, Avg Loss : 0.678900
#
# Epcoh time : 0.0분 46.41865372657776 초
# Epoch 55 End
# -------------------------------------------
#
# Epoch 56
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313272 [    0/  182]
# Batch 10 loss : 0.313300 [   80/  182]
# Batch 20 loss : 0.313286 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.041236
#
# Validation
#  Accuracy : 63.3%, Avg Loss : 0.668710
#
# Epcoh time : 0.0분 46.295732736587524 초
# Epoch 56 End
# -------------------------------------------
#
# Epoch 57
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313504 [    0/  182]
# Batch 10 loss : 0.313278 [   80/  182]
# Batch 20 loss : 0.313312 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039766
#
# Validation
#  Accuracy : 44.3%, Avg Loss : 0.872419
#
# Epcoh time : 0.0분 45.441858768463135 초
# Epoch 57 End
# -------------------------------------------
#
# Epoch 58
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313286 [    0/  182]
# Batch 10 loss : 0.313388 [   80/  182]
# Batch 20 loss : 0.313262 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.040433
#
# Validation
#  Accuracy : 39.2%, Avg Loss : 0.848617
#
# Epcoh time : 0.0분 45.84646940231323 초
# Epoch 58 End
# -------------------------------------------
#
# Epoch 59
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313267 [    0/  182]
# Batch 10 loss : 0.313567 [   80/  182]
# Batch 20 loss : 0.313289 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.041255
#
# Validation
#  Accuracy : 41.8%, Avg Loss : 0.869663
#
# Epcoh time : 0.0분 47.113473892211914 초
# Epoch 59 End
# -------------------------------------------
#
# Epoch 60
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313273 [    0/  182]
# Batch 10 loss : 0.313265 [   80/  182]
# Batch 20 loss : 0.313862 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041528
#
# Validation
#  Accuracy : 69.6%, Avg Loss : 0.588005
#
# Epcoh time : 0.0분 46.22232532501221 초
# Epoch 60 End
# -------------------------------------------
#
# Epoch 61
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.371827 [    0/  182]
# Batch 10 loss : 0.401272 [   80/  182]
# Batch 20 loss : 0.313327 [  160/  182]
# Train
#  Accuracy : 97.3%, Avg Loss : 0.043045
#
# Validation
#  Accuracy : 69.6%, Avg Loss : 0.602735
#
# Epcoh time : 0.0분 45.94486904144287 초
# Epoch 61 End
# -------------------------------------------
#
# Epoch 62
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313793 [    0/  182]
# Batch 10 loss : 0.313270 [   80/  182]
# Batch 20 loss : 0.313846 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041308
#
# Validation
#  Accuracy : 62.0%, Avg Loss : 0.667750
#
# Epcoh time : 0.0분 46.35808324813843 초
# Epoch 62 End
# -------------------------------------------
#
# Epoch 63
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313275 [    0/  182]
# Batch 10 loss : 0.313376 [   80/  182]
# Batch 20 loss : 0.313574 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.040047
#
# Validation
#  Accuracy : 51.9%, Avg Loss : 0.761291
#
# Epcoh time : 0.0분 46.34488272666931 초
# Epoch 63 End
# -------------------------------------------
#
# Epoch 64
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313309 [    0/  182]
# Batch 10 loss : 0.313267 [   80/  182]
# Batch 20 loss : 0.313269 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039679
#
# Validation
#  Accuracy : 63.3%, Avg Loss : 0.658622
#
# Epcoh time : 0.0분 46.05912256240845 초
# Epoch 64 End
# -------------------------------------------
#
# Epoch 65
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313284 [    0/  182]
# Batch 10 loss : 0.313296 [   80/  182]
# Batch 20 loss : 0.313283 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040395
#
# Validation
#  Accuracy : 60.8%, Avg Loss : 0.712890
#
# Epcoh time : 0.0분 46.37548875808716 초
# Epoch 65 End
# -------------------------------------------
#
# Epoch 66
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313265 [    0/  182]
# Batch 10 loss : 0.313277 [   80/  182]
# Batch 20 loss : 0.313753 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039787
#
# Validation
#  Accuracy : 53.2%, Avg Loss : 0.748771
#
# Epcoh time : 0.0분 46.603379249572754 초
# Epoch 66 End
# -------------------------------------------
#
# Epoch 67
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.354067 [    0/  182]
# Batch 10 loss : 0.313303 [   80/  182]
# Batch 20 loss : 0.314528 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.040127
#
# Validation
#  Accuracy : 43.0%, Avg Loss : 0.863571
#
# Epcoh time : 0.0분 46.988996744155884 초
# Epoch 67 End
# -------------------------------------------
#
# Epoch 68
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.328924 [    0/  182]
# Batch 10 loss : 0.313262 [   80/  182]
# Batch 20 loss : 0.313267 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039960
#
# Validation
#  Accuracy : 68.4%, Avg Loss : 0.636652
#
# Epcoh time : 0.0분 46.45868134498596 초
# Epoch 68 End
# -------------------------------------------
#
# Epoch 69
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.362145 [    0/  182]
# Batch 10 loss : 0.340606 [   80/  182]
# Batch 20 loss : 0.313262 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.040868
#
# Validation
#  Accuracy : 39.2%, Avg Loss : 0.891365
#
# Epcoh time : 0.0분 46.06251382827759 초
# Epoch 69 End
# -------------------------------------------
#
# Epoch 70
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313264 [    0/  182]
# Batch 10 loss : 0.313630 [   80/  182]
# Batch 20 loss : 0.313264 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040402
#
# Validation
#  Accuracy : 55.7%, Avg Loss : 0.742049
#
# Epcoh time : 0.0분 46.397605895996094 초
# Epoch 70 End
# -------------------------------------------
#
# Epoch 71
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313263 [    0/  182]
# Batch 10 loss : 0.313830 [   80/  182]
# Batch 20 loss : 0.313328 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040112
#
# Validation
#  Accuracy : 35.4%, Avg Loss : 0.952282
#
# Epcoh time : 0.0분 46.681583642959595 초
# Epoch 71 End
# -------------------------------------------
#
# Epoch 72
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.314207 [    0/  182]
# Batch 10 loss : 0.313263 [   80/  182]
# Batch 20 loss : 0.314114 [  160/  182]
# Train
#  Accuracy : 97.3%, Avg Loss : 0.042575
#
# Validation
#  Accuracy : 73.4%, Avg Loss : 0.567708
#
# Epcoh time : 0.0분 45.46273326873779 초
# Epoch 72 End
# -------------------------------------------
#
# Epoch 73
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313291 [    0/  182]
# Batch 10 loss : 0.313325 [   80/  182]
# Batch 20 loss : 0.313643 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040803
#
# Validation
#  Accuracy : 70.9%, Avg Loss : 0.582109
#
# Epcoh time : 0.0분 47.50952410697937 초
# Epoch 73 End
# -------------------------------------------
#
# Epoch 74
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.319777 [    0/  182]
# Batch 10 loss : 0.313269 [   80/  182]
# Batch 20 loss : 0.313292 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.040054
#
# Validation
#  Accuracy : 40.5%, Avg Loss : 0.890141
#
# Epcoh time : 0.0분 46.983699321746826 초
# Epoch 74 End
# -------------------------------------------
#
# Epoch 75
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313400 [    0/  182]
# Batch 10 loss : 0.313267 [   80/  182]
# Batch 20 loss : 0.313269 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040384
#
# Validation
#  Accuracy : 73.4%, Avg Loss : 0.570652
#
# Epcoh time : 0.0분 46.88908362388611 초
# Epoch 75 End
# -------------------------------------------
#
# Epoch 76
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313339 [    0/  182]
# Batch 10 loss : 0.313294 [   80/  182]
# Batch 20 loss : 0.313263 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039645
#
# Validation
#  Accuracy : 63.3%, Avg Loss : 0.655159
#
# Epcoh time : 0.0분 46.23910713195801 초
# Epoch 76 End
# -------------------------------------------
#
# Epoch 77
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313307 [    0/  182]
# Batch 10 loss : 0.313267 [   80/  182]
# Batch 20 loss : 0.313287 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040256
#
# Validation
#  Accuracy : 59.5%, Avg Loss : 0.706385
#
# Epcoh time : 0.0분 47.578227519989014 초
# Epoch 77 End
# -------------------------------------------
#
# Epoch 78
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313266 [    0/  182]
# Batch 10 loss : 0.437788 [   80/  182]
# Batch 20 loss : 0.313478 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040498
#
# Validation
#  Accuracy : 77.2%, Avg Loss : 0.530510
#
# Epcoh time : 0.0분 48.351948261260986 초
# Epoch 78 End
# -------------------------------------------
#
# Epoch 79
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313568 [    0/  182]
# Batch 10 loss : 0.313444 [   80/  182]
# Batch 20 loss : 0.315828 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.041313
#
# Validation
#  Accuracy : 62.0%, Avg Loss : 0.668038
#
# Epcoh time : 0.0분 47.6969096660614 초
# Epoch 79 End
# -------------------------------------------
#
# Epoch 80
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313351 [    0/  182]
# Batch 10 loss : 0.486240 [   80/  182]
# Batch 20 loss : 0.313323 [  160/  182]
# Train
#  Accuracy : 97.3%, Avg Loss : 0.042588
#
# Validation
#  Accuracy : 63.3%, Avg Loss : 0.646927
#
# Epcoh time : 0.0분 46.911285161972046 초
# Epoch 80 End
# -------------------------------------------
#
# Epoch 81
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.402605 [    0/  182]
# Batch 10 loss : 0.313280 [   80/  182]
# Batch 20 loss : 0.313294 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.040684
#
# Validation
#  Accuracy : 49.4%, Avg Loss : 0.762241
#
# Epcoh time : 0.0분 47.12391662597656 초
# Epoch 81 End
# -------------------------------------------
#
# Epoch 82
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.389082 [    0/  182]
# Batch 10 loss : 0.327452 [   80/  182]
# Batch 20 loss : 0.313823 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041493
#
# Validation
#  Accuracy : 67.1%, Avg Loss : 0.627102
#
# Epcoh time : 0.0분 46.261728286743164 초
# Epoch 82 End
# -------------------------------------------
#
# Epoch 83
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.337388 [    0/  182]
# Batch 10 loss : 0.313636 [   80/  182]
# Batch 20 loss : 0.324855 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040611
#
# Validation
#  Accuracy : 38.0%, Avg Loss : 0.908676
#
# Epcoh time : 0.0분 45.69685482978821 초
# Epoch 83 End
# -------------------------------------------
#
# Epoch 84
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313266 [    0/  182]
# Batch 10 loss : 0.313268 [   80/  182]
# Batch 20 loss : 0.313283 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.040708
#
# Validation
#  Accuracy : 31.6%, Avg Loss : 0.990471
#
# Epcoh time : 0.0분 47.9070508480072 초
# Epoch 84 End
# -------------------------------------------
#
# Epoch 85
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313271 [    0/  182]
# Batch 10 loss : 0.313283 [   80/  182]
# Batch 20 loss : 0.321419 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040141
#
# Validation
#  Accuracy : 74.7%, Avg Loss : 0.572665
#
# Epcoh time : 0.0분 46.68418502807617 초
# Epoch 85 End
# -------------------------------------------
#
# Epoch 86
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313262 [    0/  182]
# Batch 10 loss : 0.563295 [   80/  182]
# Batch 20 loss : 0.313332 [  160/  182]
# Train
#  Accuracy : 97.8%, Avg Loss : 0.042255
#
# Validation
#  Accuracy : 75.9%, Avg Loss : 0.554833
#
# Epcoh time : 0.0분 46.58706593513489 초
# Epoch 86 End
# -------------------------------------------
#
# Epoch 87
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313266 [    0/  182]
# Batch 10 loss : 0.313692 [   80/  182]
# Batch 20 loss : 0.313341 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.039897
#
# Validation
#  Accuracy : 59.5%, Avg Loss : 0.709155
#
# Epcoh time : 0.0분 45.828861951828 초
# Epoch 87 End
# -------------------------------------------
#
# Epoch 88
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313262 [    0/  182]
# Batch 10 loss : 0.328265 [   80/  182]
# Batch 20 loss : 0.427570 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.041485
#
# Validation
#  Accuracy : 41.8%, Avg Loss : 0.882940
#
# Epcoh time : 0.0분 46.447362184524536 초
# Epoch 88 End
# -------------------------------------------
#
# Epoch 89
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313262 [    0/  182]
# Batch 10 loss : 0.313271 [   80/  182]
# Batch 20 loss : 0.313272 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039631
#
# Validation
#  Accuracy : 59.5%, Avg Loss : 0.685534
#
# Epcoh time : 0.0분 45.93386363983154 초
# Epoch 89 End
# -------------------------------------------
#
# Epoch 90
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.315864 [    0/  182]
# Batch 10 loss : 0.313279 [   80/  182]
# Batch 20 loss : 0.313263 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039970
#
# Validation
#  Accuracy : 64.6%, Avg Loss : 0.652420
#
# Epcoh time : 0.0분 46.44081234931946 초
# Epoch 90 End
# -------------------------------------------
#
# Epoch 91
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313275 [    0/  182]
# Batch 10 loss : 0.313262 [   80/  182]
# Batch 20 loss : 0.314174 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.039985
#
# Validation
#  Accuracy : 63.3%, Avg Loss : 0.666530
#
# Epcoh time : 0.0분 46.179781436920166 초
# Epoch 91 End
# -------------------------------------------
#
# Epoch 92
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313263 [    0/  182]
# Batch 10 loss : 0.332450 [   80/  182]
# Batch 20 loss : 0.313263 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040410
#
# Validation
#  Accuracy : 59.5%, Avg Loss : 0.713141
#
# Epcoh time : 0.0분 46.072585105895996 초
# Epoch 92 End
# -------------------------------------------
#
# Epoch 93
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313278 [    0/  182]
# Batch 10 loss : 0.313263 [   80/  182]
# Batch 20 loss : 0.313267 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039632
#
# Validation
#  Accuracy : 62.0%, Avg Loss : 0.679326
#
# Epcoh time : 0.0분 46.22890305519104 초
# Epoch 93 End
# -------------------------------------------
#
# Epoch 94
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313399 [    0/  182]
# Batch 10 loss : 0.313274 [   80/  182]
# Batch 20 loss : 0.313263 [  160/  182]
# Train
#  Accuracy : 98.9%, Avg Loss : 0.040863
#
# Validation
#  Accuracy : 38.0%, Avg Loss : 0.901178
#
# Epcoh time : 0.0분 45.72323560714722 초
# Epoch 94 End
# -------------------------------------------
#
# Epoch 95
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313262 [    0/  182]
# Batch 10 loss : 0.313265 [   80/  182]
# Batch 20 loss : 0.313922 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039674
#
# Validation
#  Accuracy : 39.2%, Avg Loss : 0.898867
#
# Epcoh time : 0.0분 45.8634147644043 초
# Epoch 95 End
# -------------------------------------------
#
# Epoch 96
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313751 [    0/  182]
# Batch 10 loss : 0.313273 [   80/  182]
# Batch 20 loss : 0.313381 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040308
#
# Validation
#  Accuracy : 43.0%, Avg Loss : 0.843249
#
# Epcoh time : 0.0분 46.258569955825806 초
# Epoch 96 End
# -------------------------------------------
#
# Epoch 97
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313364 [    0/  182]
# Batch 10 loss : 0.313372 [   80/  182]
# Batch 20 loss : 0.313277 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040090
#
# Validation
#  Accuracy : 51.9%, Avg Loss : 0.763188
#
# Epcoh time : 0.0분 47.85636520385742 초
# Epoch 97 End
# -------------------------------------------
#
# Epoch 98
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.315678 [    0/  182]
# Batch 10 loss : 0.313700 [   80/  182]
# Batch 20 loss : 0.313354 [  160/  182]
# Train
#  Accuracy : 99.5%, Avg Loss : 0.040315
#
# Validation
#  Accuracy : 67.1%, Avg Loss : 0.616751
#
# Epcoh time : 0.0분 47.623690366744995 초
# Epoch 98 End
# -------------------------------------------
#
# Epoch 99
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.316835 [    0/  182]
# Batch 10 loss : 0.373302 [   80/  182]
# Batch 20 loss : 0.313283 [  160/  182]
# Train
#  Accuracy : 98.4%, Avg Loss : 0.040543
#
# Validation
#  Accuracy : 55.7%, Avg Loss : 0.702153
#
# Epcoh time : 0.0분 46.07377767562866 초
# Epoch 99 End
# -------------------------------------------
#
# Epoch 100
# -------------------------------------------
# 데이터 사이즈 :  182
# Batch 0 loss : 0.313703 [    0/  182]
# Batch 10 loss : 0.313262 [   80/  182]
# Batch 20 loss : 0.313283 [  160/  182]
# Train
#  Accuracy : 100.0%, Avg Loss : 0.039798
#
# Validation
#  Accuracy : 72.2%, Avg Loss : 0.600085
#
# Epcoh time : 0.0분 45.64646601676941 초
# Epoch 100 End
# -------------------------------------------
#
# Epoch 걸린 시간 :  77.0  분 13.66507339477539  초

# %% [markdown]
# Plot Train Acc, loss

# %%
ep=[i for i in range(1, CFG['EPOCHS']+1)]

# %%
plt.figure(figsize=(15,7))
plt.title('train_loss_info')
plt.plot(ep, train_loss_info, label='train')
plt.legend()

# %% [markdown]
# Plot val Acc, loss

# %%
plt.figure(figsize=(15,7))
plt.title('val_loss_info')
plt.plot(ep,val_loss_info, label='val')
plt.legend()

# %% [markdown]
# # 13. Save Model

# %%
PATH='C:\\Users\\PC00\\Desktop\\ASD_data\\model\\T2\\'

# %%
torch.save(model, PATH+'model.pt') #전체 모델 저장
torch.save(model.state_dict(), PATH+'model_state_dict.pt') #모델 객체의 state_dict 저장
torch.save({
    'model':model.state_dict(),
    'optimizer':optimizer.state_dict()
}, PATH+'all.tar') #여러 가지 값 저장, 학습 중 진행 상황 저장을 위해 epoch, loss 값 등 일반 scalar 값 저장 가능

# %% [markdown]
# # 14. Test

# %%
model=torch.load(PATH+'model.pt') #전체 모델을 통째로 불러옴
model.load_state_dict(torch.load(PATH+'model_state_dict.pt')) #state_dict를 불러 온 후, 모델에 저장

checkpoint = torch.load(PATH + 'all.tar')   # dict 불러오기
model.load_state_dict(checkpoint['model'])
optimizer.load_state_dict(checkpoint['optimizer'])

model.to(device)
# Out:
# ResNet18(
#   (conv1): Conv3d(1, 64, kernel_size=(7, 7, 7), stride=(1, 2, 2), padding=(3, 3, 3), bias=False)
#   (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=64, out_features=4, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=4, out_features=64, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=64, out_features=4, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=4, out_features=64, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv3d(64, 128, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=128, out_features=8, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=8, out_features=128, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=128, out_features=8, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=8, out_features=128, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv3d(128, 256, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=256, out_features=16, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=16, out_features=256, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=256, out_features=16, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=16, out_features=256, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=512, out_features=32, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=32, out_features=512, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (cbam): CBAM(
#         (ChannelGate): ChannelGate(
#           (mlp): Sequential(
#             (0): Flatten()
#             (1): Linear(in_features=512, out_features=32, bias=True)
#             (2): ReLU()
#             (3): Linear(in_features=32, out_features=512, bias=True)
#           )
#         )
#         (SpatialGate): SpatialGate(
#           (compress): ChannelPool()
#           (spatial): BasicConv(
#             (conv): Conv3d(2, 1, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#             (bn): BatchNorm3d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool3d(output_size=(1, 1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
#sensitivity
#양성인 것중에 양성으로 판별

#specificity
#음성인 것중에 음성으로 판별

def true_positive(p,t):
    l=len(p)
    cnt=0
    for i in range(l):
        if t[i]==1 and p[i]==1:
            cnt+=1
            
    return cnt


def true_negative(p,t):
    l=len(p)
    cnt=0
    for i in range(l):
        if t[i]==0 and p[i]==0:
            cnt+=1
    
    return cnt

# %%
def test_loop(dataloader,model, loss_fn, test_asd, test_tc):
    size=len(dataloader.dataset)
    num_batches=len(dataloader)
    model.eval()
    
    test_loss, correct=0,0
    
    TP,TN=0,0
    
    with torch.no_grad():
        for X,y in dataloader:
            X=Variable(X.to(device).float())
            y=Variable(y.to(device).float())
            
            pred=model(X)
            
            #loss
            test_loss+=loss_fn(pred, y).item()
            #accuracy
            correct+=(pred.argmax(1)==y.argmax(1)).type(torch.float).sum().item()
            print(pred.argmax(1))
            print(y.argmax(1))
            print()
            TP+=true_positive(pred.argmax(1), y.argmax(1))
            TN+=true_negative(pred.argmax(1), y.argmax(1))
    
    FN=test_asd-TP
    FP=test_tc-TN
    test_loss/=num_batches
    correct/=size
    
    print(f"Test Error\n Accuracy : {(100*correct):>0.1f}%, Avg Loss : {test_loss:>8f}\n")
    print(f"True Positive : {TP}\nTrue Negative : {TN}\nFalse Positive : {FP}\nFalse Negative : {FN}\n")
    return (TP/(TP+FN))*100, (TN/(FP+TN))*100, (TP/(TP+FP))*100, (TN/(FN+TN))*100

# %%
test_asd=10
test_tc=10

start=time.time()

sensitivity, specificity, PPV, NPV=test_loop(test_dataloader ,model, loss_fn, test_asd, test_tc)

end=time.time()

print(f"Test 걸린 시간 : {(end-start)//60} 분 {(end-start)%60:.1f} 초")
# Out:
# tensor([1, 0, 1, 0, 0, 0, 0, 1], device='cuda:0')
# tensor([1, 0, 1, 0, 1, 1, 0, 1], device='cuda:0')
#
# tensor([0, 1, 1, 0, 1, 1, 1, 1], device='cuda:0')
# tensor([0, 1, 0, 1, 0, 1, 0, 1], device='cuda:0')
#
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([0, 0, 1, 0], device='cuda:0')
#
# Test Error
#  Accuracy : 60.0%, Avg Loss : 0.765184
#
# True Positive : 7
# True Negative : 5
# False Positive : 5
# False Negative : 3
#
# Test 걸린 시간 : 0.0 분 4.6 초

# %%
print(f"Sensitivity : {sensitivity:.3f}%")
print(f"Specificity : {specificity:.3f}%")
print(f"PPV : {PPV:.3f}%")
print(f"NPV : {NPV:.3f}%")
# Out:
# Sensitivity : 70.000%
# Specificity : 50.000%
# PPV : 58.333%
# NPV : 62.500%
